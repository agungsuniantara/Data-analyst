# %%
username = "admin"
if username == "admin":
     print("Selamat Datang Admin!")

a = 20
b = 30
if b > a:
  print("b lebih besar dari a") #error
# Out:
# Selamat Datang Admin!
# b lebih besar dari a

# %%
username = "user"
if username == "admin":
     print("Selamat Datang Admin!")
print("ini akan selalu dieksekusi...")
# Out:
# ini akan selalu dieksekusi...

# %%
nilai = int(input("Masukan Nilai Ujian = "))
if(nilai > 60):
     print("Selamat Anda Lulus Ujian!")
else:
     print("Maaf Anda Harus Mengulang Tahun Depan")
# Out:
# Masukan Nilai Ujian = 10
# Maaf Anda Harus Mengulang Tahun Depan

# %%
username = input("Masukan Username Anda = ")
if(username == "admin"):
    print("Salamat Datang Admin!")
elif(username == "robert"):
    print("Selamat Datang Robert di Koding Akademi!")
else:
    print("Maaf Anda Tidak Terdaftar Sebagai Pengguna")
# Out:
# Masukan Username Anda = dsadas
# Maaf Anda Tidak Terdaftar Sebagai Pengguna

# %%
username = input("Masukan Username Anda = ")
password = input("Masukan Password Anda = ")
if(username == "admin" and password=="123"):
     print("Selamat Datang di Koding Akademi!")
else:
     print("Username dan atau Password salah!")
# Out:
# Masukan Username Anda = agung
# Masukan Password Anda = 123
# Username dan atau Password salah!

# %%
#assignment 1

nilai = int(input("Masukan nilai = "))

if nilai >= 0 and nilai <= 50:
  print(f"nilai {nilai} adalah D")
elif nilai > 50 and nilai <= 70:
  print(f"nilai {nilai} adalah C")
elif nilai > 70 and nilai <= 80:
  print(f"nilai {nilai} adalah B")
elif nilai > 80 and nilai <= 100:
  print(f"nilai {nilai} adalah A")
else:
  print("nilai tidak sesuai ketentuan !")
# Out:
# Masukan nilai = 101
# nilai tidak sesuai ketentuan !

# %%
#assignment 2

num = int(input("masukkan angka = "))

if num % 2 == 0 :
  print(f"{num} adalah bilangan genap")
else:
  print(f"{num} adalah bilangan ganjil")
# Out:
# masukkan angka = 1
# 1 adalah bilangan ganjil

# %%
#assignment 3

no = 0
for i in range(0,3):
  no += 1
  kwh = int(input(f"masukkan kwh {no} = "))
  if no == 1:
    if kwh >= 0 and kwh <= 100:
      harga = 0
      total_kwh = kwh * harga
      print(f"total harga kwh pertama = Rp {total_kwh} (gratis)")
    elif kwh > 100 and kwh < 200:
        harga = 5
        total_kwh = kwh * harga
        print(f"total harga kwh kedua = Rp {total_kwh}")
    elif kwh >= 200:
        harga = 10
        total_kwh = kwh * harga
        print(f"total harga kwh pertama = Rp {total_kwh}")

  if no == 2:
    if kwh > 0 and kwh < 200:
        harga = 5
        total_kwh = kwh * harga
        print(f"total harga kwh kedua = Rp {total_kwh}")
    elif kwh >= 200:
        harga = 10
        total_kwh = kwh * harga
        print(f"total harga kwh pertama = Rp {total_kwh}")

  if no == 3:
    if kwh > 0:
        harga = 10
        total_kwh = kwh * harga
        print(f"total harga kwh kedua = Rp {total_kwh}")
# Out:
# masukkan kwh 1 = 100
# total harga kwh pertama = Rp 0 (gratis)
# masukkan kwh 2 = 100
# total harga kwh kedua = Rp 500
# masukkan kwh 3 = 100
# total harga kwh kedua = Rp 1000
