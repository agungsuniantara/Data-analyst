# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/satriabimantara/DataAnalystBootcamp/master/datasets/bike_price_dataset/Bike%20Price.csv'
contoh = pd.read_csv(url)
contoh
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
import pandas as pd

url = "C:/Users/suniantara/Desktop/bootcamp/data/Data-Penindakan-Pelanggaran-Lalu-Lintas.csv"
data = pd.read_csv(url)
data
# Out:
#        bulan                   wilayah  bap_tilang  stop_operasi  bap_polisi  \
# 0    Januari             Bidang Dalops          44           139           0
# 1    Januari    Sudinhub Jakarta Pusat          47             2          52
# 2    Januari    Sudinhub Jakarta Utara         166            27           0
# 3    Januari  Sudinhub Jakarta Selatan          44             1           0
# 4    Januari    Sudinhub Jakarta Barat         184            70           0
# 5    Januari    Sudinhub Jakarta Timur         191           141           0
# 6   Februari             Bidang Dalops          37           143           0
# 7   Februari    Sudinhub Jakarta Pusat          48             7          42
# 8   Februari    Sudinhub Jakarta Utara         251            27          31
# 9   Februari  Sudinhub Jakarta Selatan         129            12           0
# 10  Februari    Sudinhub Jakarta Barat         229            60           0
# ...

# %%
contoh.columns = ['Tanggal', 'ODP', 'PDP', 'Kasus Positif', 'Kasus Sembuh','Kasus Meninggal', 'Kasus']
contoh
# Out:
#                                   Tanggal     ODP   PDP Kasus Positif  \
# 0               Royal Enfield Classic 350  175000  2019    Individual
# 1                               Honda Dio   45000  2017    Individual
# 2     Royal Enfield Classic Gunmetal Grey  150000  2018    Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]   65000  2015    Individual
# 4                   Yamaha SZ [2013-2014]   20000  2011    Individual
# ...                                   ...     ...   ...           ...
# 1056                            Activa 3g   17000  2010    Individual
# 1057                     Honda CB twister   16000  2012    Individual
# 1058                   Bajaj Discover 125   15000  2013    Individual
# 1059                       Honda CB Shine   12000  2009    Individual
# 1060                     Bajaj Pulsar 150   10000  2008    Individual
#
#      Kasus Sembuh  Kasus Meninggal     Kasus
# 0       1st owner              350       NaN
# ...

# %%
print("Baris : ",contoh.shape[0], "Columns : ", contoh.shape[1])
# Out:
# Baris :  1061 Columns :  7

# %%
contoh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tanggal          1061 non-null   object
#  1   ODP              1061 non-null   int64
#  2   PDP              1061 non-null   int64
#  3   Kasus Positif    1061 non-null   object
#  4   Kasus Sembuh     1061 non-null   object
#  5   Kasus Meninggal  1061 non-null   int64
#  6   Kasus            626 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 58.1+ KB

# %%
contoh.head()
# Out:
#                                Tanggal     ODP   PDP Kasus Positif  \
# 0            Royal Enfield Classic 350  175000  2019    Individual
# 1                            Honda Dio   45000  2017    Individual
# 2  Royal Enfield Classic Gunmetal Grey  150000  2018    Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]   65000  2015    Individual
# 4                Yamaha SZ [2013-2014]   20000  2011    Individual
#
#   Kasus Sembuh  Kasus Meninggal     Kasus
# 0    1st owner              350       NaN
# 1    1st owner             5650       NaN
# 2    1st owner            12000  148114.0
# 3    1st owner            23000   89643.0
# 4    2nd owner            21000       NaN

# %%
contoh.tail()
# Out:
#                  Tanggal    ODP   PDP Kasus Positif Kasus Sembuh  \
# 1056           Activa 3g  17000  2010    Individual    1st owner
# 1057    Honda CB twister  16000  2012    Individual    1st owner
# 1058  Bajaj Discover 125  15000  2013    Individual    2nd owner
# 1059      Honda CB Shine  12000  2009    Individual    1st owner
# 1060    Bajaj Pulsar 150  10000  2008    Individual    1st owner
#
#       Kasus Meninggal    Kasus
# 1056           500000  52000.0
# 1057            33000  51000.0
# 1058            35000  57000.0
# 1059            53000  58000.0
# 1060            92233  75000.0

# %%
contoh.tail(3)
# Out:
#                  Tanggal    ODP   PDP Kasus Positif Kasus Sembuh  \
# 1058  Bajaj Discover 125  15000  2013    Individual    2nd owner
# 1059      Honda CB Shine  12000  2009    Individual    1st owner
# 1060    Bajaj Pulsar 150  10000  2008    Individual    1st owner
#
#       Kasus Meninggal    Kasus
# 1058            35000  57000.0
# 1059            53000  58000.0
# 1060            92233  75000.0

# %%
#assignment

import pandas as pd

paket = pd.read_csv('C:/Users/suniantara/Desktop/bootcamp/data/package_tourism.csv')
paket
# Out:
#     Package      City                   Place_Tourism1  \
# 0         1   Jakarta                Pasar Tanah Abang
# 1         2   Jakarta                Pasar Tanah Abang
# 2         3   Jakarta            Perpustakaan Nasional
# 3         4   Jakarta                     Pulau Tidung
# 4         5   Jakarta            Museum Satria Mandala
# ..      ...       ...                              ...
# 95       96  Surabaya      Ekowisata Mangrove Wonorejo
# 96       97  Surabaya                Ciputra Waterpark
# 97       98  Surabaya    Museum Kesehatan Dr. Adhyatma
# 98       99  Surabaya  Taman Ekspresi Dan Perpustakaan
# 99      100  Surabaya              Taman Buah Surabaya
#
#               Place_Tourism2                  Place_Tourism3  \
# 0               Taman Ayodya                  Museum Tekstil
# 1         Pasar Taman Puring            Pasar Petak Sembilan
# 2                      Monas                 Masjid Istiqlal
# ...

# %%
paket.rename(columns = {'Package' : 'Paket', 'City' : 'Kota'})
# Out:
#     Paket      Kota                   Place_Tourism1  \
# 0       1   Jakarta                Pasar Tanah Abang
# 1       2   Jakarta                Pasar Tanah Abang
# 2       3   Jakarta            Perpustakaan Nasional
# 3       4   Jakarta                     Pulau Tidung
# 4       5   Jakarta            Museum Satria Mandala
# ..    ...       ...                              ...
# 95     96  Surabaya      Ekowisata Mangrove Wonorejo
# 96     97  Surabaya                Ciputra Waterpark
# 97     98  Surabaya    Museum Kesehatan Dr. Adhyatma
# 98     99  Surabaya  Taman Ekspresi Dan Perpustakaan
# 99    100  Surabaya              Taman Buah Surabaya
#
#               Place_Tourism2                  Place_Tourism3  \
# 0               Taman Ayodya                  Museum Tekstil
# 1         Pasar Taman Puring            Pasar Petak Sembilan
# 2                      Monas                 Masjid Istiqlal
# 3             Pulau Bidadari                      Pulau Pari
# ...

# %%
paket.columns = ['Paket','Kota','Destinasi 1','Destinasi 2','Destinasi 3','Destinasi 4','Destinasi 5']
paket
# Out:
#     Paket      Kota                      Destinasi 1  \
# 0       1   Jakarta                Pasar Tanah Abang
# 1       2   Jakarta                Pasar Tanah Abang
# 2       3   Jakarta            Perpustakaan Nasional
# 3       4   Jakarta                     Pulau Tidung
# 4       5   Jakarta            Museum Satria Mandala
# ..    ...       ...                              ...
# 95     96  Surabaya      Ekowisata Mangrove Wonorejo
# 96     97  Surabaya                Ciputra Waterpark
# 97     98  Surabaya    Museum Kesehatan Dr. Adhyatma
# 98     99  Surabaya  Taman Ekspresi Dan Perpustakaan
# 99    100  Surabaya              Taman Buah Surabaya
#
#                  Destinasi 2                     Destinasi 3  \
# 0               Taman Ayodya                  Museum Tekstil
# 1         Pasar Taman Puring            Pasar Petak Sembilan
# 2                      Monas                 Masjid Istiqlal
# 3             Pulau Bidadari                      Pulau Pari
# ...

# %%
jumlah = len(paket)
jumlah
# Out:
# 100

# %%
paket.head(10)
# Out:
#    Paket     Kota                         Destinasi 1  \
# 0      1  Jakarta                   Pasar Tanah Abang
# 1      2  Jakarta                   Pasar Tanah Abang
# 2      3  Jakarta               Perpustakaan Nasional
# 3      4  Jakarta                        Pulau Tidung
# 4      5  Jakarta               Museum Satria Mandala
# 5      6  Jakarta  Waterboom PIK (Pantai Indah Kapuk)
# 6      7  Jakarta                  Alive Museum Ancol
# 7      8  Jakarta                            Kota Tua
# 8      9  Jakarta           Galeri Nasional Indonesia
# 9     10  Jakarta             Taman Impian Jaya Ancol
#
#                    Destinasi 2            Destinasi 3  \
# 0                 Taman Ayodya         Museum Tekstil
# 1           Pasar Taman Puring   Pasar Petak Sembilan
# 2                        Monas        Masjid Istiqlal
# 3               Pulau Bidadari             Pulau Pari
# 4                Museum Wayang  Museum Bahari Jakarta
# ...

# %%
paket.tail(10)
# Out:
#     Paket      Kota                      Destinasi 1  \
# 90     91  Surabaya      Ekowisata Mangrove Wonorejo
# 91     92  Surabaya              Taman Kunang-Kunang
# 92     93  Surabaya    Museum TNI AL Loka Jala Crana
# 93     94  Surabaya              Taman Buah Surabaya
# 94     95  Surabaya    Museum TNI AL Loka Jala Crana
# 95     96  Surabaya      Ekowisata Mangrove Wonorejo
# 96     97  Surabaya                Ciputra Waterpark
# 97     98  Surabaya    Museum Kesehatan Dr. Adhyatma
# 98     99  Surabaya  Taman Ekspresi Dan Perpustakaan
# 99    100  Surabaya              Taman Buah Surabaya
#
#                         Destinasi 2                            Destinasi 3  \
# 90            Taman Harmoni Keputih       Taman Air Mancur Menari Kenjeran
# 91  Taman Ekspresi Dan Perpustakaan       Taman Air Mancur Menari Kenjeran
# 92           Klenteng Sanggar Agung  Museum Sepuluh Nopember Kota Surabaya
# 93                    Taman Pelangi                    Hutan Bambu Keputih
# ...

# %%
import pandas as pd

json = pd.read_json('https://microsoftedge.github.io/Demos/json-dummy-data/64KB.json')
json
# Out:
#                        name   language                id  \
# 0             Adeel Solangi     Sindhi  V59OF92YF627HFY0
# 1             Afzal Ghaffar     Sindhi  ENTOCR13RSCLZ6KU
# 2             Aamir Solangi     Sindhi  IAKPO3R4761JDRVG
# 3             Abla Dilmurat     Uyghur  5ZVOEPMJUI4MB4EN
# 4                  Adil Eli     Uyghur  6VTI8X6LL0MMPJCC
# ..                      ...        ...               ...
# 192  Kristín Sigurðardóttir  Icelandic  ZP5TBBYX6RI2UJ31
# 193            Rohini Vasav      Hindi  UEFML43TCGS04KWM
# 194            Sunil Kapoor      Hindi  VY2A0APGVHK5NAW2
# 195          Zamokuhle Zulu    isiZulu  XU7BX2F8M5PVZ1EF
# 196           Bhupesh Menon      Hindi  0CEPNRDV98KT3ORP
#
#                                                    bio  version
# 0    Donec lobortis eleifend condimentum. Cras dict...     6.10
# 1    Aliquam sollicitudin ante ligula, eget malesua...     1.88
# 2    Vestibulum pharetra libero et velit gravida eu...     7.27
# ...

# %%
json.head(10)
# Out:
#                 name  language                id  \
# 0      Adeel Solangi    Sindhi  V59OF92YF627HFY0
# 1      Afzal Ghaffar    Sindhi  ENTOCR13RSCLZ6KU
# 2      Aamir Solangi    Sindhi  IAKPO3R4761JDRVG
# 3      Abla Dilmurat    Uyghur  5ZVOEPMJUI4MB4EN
# 4           Adil Eli    Uyghur  6VTI8X6LL0MMPJCC
# 5        Adile Qadir    Uyghur  F2KEU5L7EHYSYFTT
# 6  Abdukerim Ibrahim    Uyghur  LO6DVTZLRK68528I
# 7          Adil Abro    Sindhi  LJRIULRNJFCNZJAJ
# 8   Afonso Vilarchán  Galician  JMCL0CXNXHPL1GBC
# 9      Mark Schembri   Maltese  KU4T500C830697CW
#
#                                                  bio  version
# 0  Donec lobortis eleifend condimentum. Cras dict...     6.10
# 1  Aliquam sollicitudin ante ligula, eget malesua...     1.88
# 2  Vestibulum pharetra libero et velit gravida eu...     7.27
# 3  Donec lobortis eleifend condimentum. Morbi ac ...     2.53
# 4  Vivamus id faucibus velit, id posuere leo. Mor...     6.49
# ...

# %%
json.tail(10)
# Out:
#                        name   language                id  \
# 187             Meena Dubey      Hindi  GCJGYXSPDEFF9BTN
# 188         Chandrika Gupta      Hindi  7KFJHS86WKTL6Q12
# 189          Akhilesh Khare      Hindi  ATINHMT01VNMMDCP
# 190         Motsumi Basiang   Setswana  MUELSFQENUOHGBZ3
# 191           Neha Benjaree      Hindi  5VTSZUD0SA9JVL40
# 192  Kristín Sigurðardóttir  Icelandic  ZP5TBBYX6RI2UJ31
# 193            Rohini Vasav      Hindi  UEFML43TCGS04KWM
# 194            Sunil Kapoor      Hindi  VY2A0APGVHK5NAW2
# 195          Zamokuhle Zulu    isiZulu  XU7BX2F8M5PVZ1EF
# 196           Bhupesh Menon      Hindi  0CEPNRDV98KT3ORP
#
#                                                    bio  version
# 187  Vestibulum ante ipsum primis in faucibus orci ...     2.95
# 188  Aliquam sollicitudin ante ligula, eget malesua...     5.35
# 189  Donec congue sapien vel euismod interdum. Susp...     3.68
# 190  Cras dictum dolor lacinia lectus vehicula rutr...     5.23
# ...

# %%
ambil = ['language','id','bio','version']

json.drop(ambil, inplace=True, axis = 1)

# %%
json.head()
# Out:
#             name
# 0  Adeel Solangi
# 1  Afzal Ghaffar
# 2  Aamir Solangi
# 3  Abla Dilmurat
# 4       Adil Eli

# %%
total = len(json)
total
# Out:
# 197

# %%
import pandas as pd

data5 = pd.read_csv('C:/Users/suniantara/Desktop/bootcamp/data/contoh.csv')
data5
# Out:
#    NO     Pengetahuan  Frekuensi  Pengetahuan.1  Frekuensi.1
# 0   1   Kurang dari 6          0   Lebih dari 6           60
# 1   2  Kurang dari 11          4  Lebih dari 11           56
# 2   3  Kurang dari 16         21  Lebih dari 16           39
# 3   4  Kurang dari 21         33  Lebih dari 21           27
# 4   5  Kurang dari 26         45  Lebih dari 26           15
# 5   6  Kurang dari 31         51  Lebih dari 31            9
# 6   7  Kurang dari 36         55  Lebih dari 36            5
# 7   8  Kurang dari 41         60  Lebih dari 41            0

# %%
import pandas as pd
import numpy as np

json = pd.read_json('https://raw.githubusercontent.com/mediatechid/bootcamp-data-analyst/main/zomato_resto_file1.json')
json
# Out:
#      results_found                                        restaurants  \
# 0          17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 1           4748.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 2          13786.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 3          10224.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 4           7039.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# ..             ...                                                ...
# 474            NaN                                                NaN
# 475            NaN                                                NaN
# 476            NaN                                                NaN
# 477            NaN                                                NaN
# 478            NaN                                                NaN
#
#      results_shown  results_start             message   code status
# ...

# %%
def contoh(data):
    if len(data)!=0:
        restaurant_information = data[0]['restaurant']
        restaurant_name = restaurant_information['name']
        return restaurant_name
    else:
        return np.nan

json['restaurants'] = json['restaurants'].apply()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_596\1548114028.py in <module>
#       7         return np.nan
#       8
# ----> 9 json['restaurants'] = json['restaurants'].apply()
#
# NameError: name 'json' is not defined

# %%
for restoran in json['restaurants'].unique():
    print(restoran)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8380\1968769308.py in <module>
# ----> 1 for restoran in data_json['restaurants'].unique():
#       2     print(restoran)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unique(self)
#    2086         Categories (3, object): ['a' < 'b' < 'c']
#    2087         """
# -> 2088         return super().unique()
#    2089
#    2090     @overload
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in unique(self)
#     987                     result = np.asarray(result)
#     988         else:
# --> 989             result = unique1d(values)
#     990
#     991         return result
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     438
#     439     table = htable(len(values))
# --> 440     uniques = table.unique(values)
# ...
