# %%
import matplotlib as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

url = "C:/Users/suniantara/Desktop/bootcamp/data/dataset/heart.csv"
url2 = "C:/Users/suniantara/Desktop/bootcamp/data/dataset/country_vaccinations.csv"

data1 = pd.read_csv(url)
data2 = pd.read_csv(url2)
data1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
data1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
data1['age'].hist()
# Out:
# <AxesSubplot:>

# %%
data1['sex'].hist()
# Out:
# <AxesSubplot:>

# %%
data_zimbabwe = data2[data2['country'] == 'Zimbabwe'].dropna()
data_zimbabwe
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 53376  Zimbabwe      ZWE  2021-03-22             44120.0            43840.0
# 53377  Zimbabwe      ZWE  2021-03-23             45743.0            44681.0
# 53378  Zimbabwe      ZWE  2021-03-24             52439.0            49950.0
# 53379  Zimbabwe      ZWE  2021-03-25             59533.0            55438.0
# 53380  Zimbabwe      ZWE  2021-03-26             68208.0            61639.0
# ...         ...      ...         ...                 ...                ...
# 53590  Zimbabwe      ZWE  2021-10-22           5814790.0          3271638.0
# 53591  Zimbabwe      ZWE  2021-10-23           5826876.0          3276746.0
# 53592  Zimbabwe      ZWE  2021-10-24           5836363.0          3281618.0
# 53593  Zimbabwe      ZWE  2021-10-25           5848934.0          3287996.0
# 53594  Zimbabwe      ZWE  2021-10-26           5866629.0          3294687.0
#
# ...

# %%
data_zimbabwe['people_vaccinated'].plot()
# Out:
# <AxesSubplot:>

# %%
#assignment

import matplotlib.pyplot as plt
import pandas as pd

url = "C:/Users/suniantara/Desktop/bootcamp/data/netflix_titles-1.csv"

data = pd.read_csv(url)
data
# Out:
#     show_id     type                                              title  \
# 0        s1    Movie                               Dick Johnson Is Dead
# 1        s2  TV Show                                      Blood & Water
# 2        s3  TV Show                                          Ganglands
# 3        s4  TV Show                              Jailbirds New Orleans
# 4       s24    Movie       Go! Go! Cory Carson: Chrissy Takes the Wheel
# ..      ...      ...                                                ...
# 103     s20  TV Show                                             Jaguar
# 104     s96  TV Show                                         The Circle
# 105     s97    Movie  If I Leave Here Tomorrow: A Film About Lynyrd ...
# 106     s98  TV Show                                         Kid Cosmic
# 107     s99  TV Show                          Octonauts: Above & Beyond
#
#                     director  \
# 0            Kirsten Johnson
# 1                        NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       108 non-null    object
#  1   type          108 non-null    object
#  2   title         108 non-null    object
#  3   director      67 non-null     object
#  4   cast          97 non-null     object
#  5   country       62 non-null     object
#  6   date_added    108 non-null    object
#  7   release_year  108 non-null    int64
#  8   rating        108 non-null    object
#  9   duration      108 non-null    object
#  10  listed_in     108 non-null    object
#  11  description   108 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 10.2+ KB

# %%
data['date_added'] = pd.to_datetime(data['date_added'])
data
# Out:
#     show_id     type                                              title  \
# 0        s1    Movie                               Dick Johnson Is Dead
# 1        s2  TV Show                                      Blood & Water
# 2        s3  TV Show                                          Ganglands
# 3        s4  TV Show                              Jailbirds New Orleans
# 4       s24    Movie       Go! Go! Cory Carson: Chrissy Takes the Wheel
# ..      ...      ...                                                ...
# 103     s20  TV Show                                             Jaguar
# 104     s96  TV Show                                         The Circle
# 105     s97    Movie  If I Leave Here Tomorrow: A Film About Lynyrd ...
# 106     s98  TV Show                                         Kid Cosmic
# 107     s99  TV Show                          Octonauts: Above & Beyond
#
#                     director  \
# 0            Kirsten Johnson
# 1                        NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       108 non-null    object
#  1   type          108 non-null    object
#  2   title         108 non-null    object
#  3   director      67 non-null     object
#  4   cast          97 non-null     object
#  5   country       62 non-null     object
#  6   date_added    108 non-null    datetime64[ns]
#  7   release_year  108 non-null    int64
#  8   rating        108 non-null    object
#  9   duration      108 non-null    object
#  10  listed_in     108 non-null    object
#  11  description   108 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 10.2+ KB

# %%
data = data.dropna()
data
# Out:
#     show_id     type                                              title  \
# 8        s8    Movie                                            Sankofa
# 9        s9  TV Show                      The Great British Baking Show
# 11      s10    Movie                                       The Starling
# 15      s13    Movie                                       Je Suis Karl
# 27      s25    Movie                                              Jeans
# 30      s28    Movie                                          Grown Ups
# 31      s29    Movie                                         Dark Skies
# 32      s30    Movie                                           Paranoia
# 41      s39    Movie                                Birth of the Dragon
# 45      s42    Movie                                               Jaws
# 46      s43    Movie                                             Jaws 2
# 47      s44    Movie                                             Jaws 3
# ...

# %%
data['release_year'].describe()
# Out:
# count      34.000000
# mean     2007.029412
# std        12.278301
# min      1975.000000
# 25%      2002.250000
# 50%      2009.500000
# 75%      2017.750000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
data['release_year'] = data['release_year'].astype('int')

# %%
data.hist(column='release_year', by='type')
# Out:
# array([<AxesSubplot:title={'center':'Movie'}>,
#        <AxesSubplot:title={'center':'TV Show'}>], dtype=object)

# %%
movie = data[(data['release_year'] == 2018) & (data['type'] == 'Movie')]
movie['title']
# Out:
# 79                                          King of Boys
# 101                                            Show Dogs
# 105    If I Leave Here Tomorrow: A Film About Lynyrd ...
# Name: title, dtype: object

# %%
data['date_added'] = data['date_added'].astype('str')

# %%
data[["date_added_year", "date_added_month","date_added_day"]] = data["date_added"].str.split("-", expand = True)
data
# Out:
#     show_id     type                                              title  \
# 8        s8    Movie                                            Sankofa
# 9        s9  TV Show                      The Great British Baking Show
# 11      s10    Movie                                       The Starling
# 15      s13    Movie                                       Je Suis Karl
# 27      s25    Movie                                              Jeans
# 30      s28    Movie                                          Grown Ups
# 31      s29    Movie                                         Dark Skies
# 32      s30    Movie                                           Paranoia
# 41      s39    Movie                                Birth of the Dragon
# 45      s42    Movie                                               Jaws
# 46      s43    Movie                                             Jaws 2
# 47      s44    Movie                                             Jaws 3
# ...
