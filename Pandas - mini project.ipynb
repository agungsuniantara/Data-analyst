# %%
import pandas as pd

url = 'C:/Users/suniantara/Desktop/bootcamp/data/bali_tourist.csv'
data = pd.read_csv(url)
data
# Out:
#      year                 area               country  January  February  \
# 0    2019        ASIA PACIFIC             AUSTRALIAN    95536     67474
# 1    2019        ASIA PACIFIC                 BHUTAN       60        30
# 2    2019        ASIA PACIFIC             BANGLADESH     2262      2094
# 3    2019        ASIA PACIFIC                   FIJI       91        73
# 4    2019        ASIA PACIFIC               HONGKONG     1313      1367
# ..    ...                  ...                   ...      ...       ...
# 357  2018          MIDDLE EAST                TURKEY      899       615
# 358  2018          MIDDLE EAST  UNITED ARAB EMIRATES      170       132
# 359  2018          MIDDLE EAST                 YAMAN       98        49
# 360  2018          MIDDLE EAST                JORDAN      225       153
# 361  2018  OTHER NATIONALITIES   OTHER NATIONALITIES     6952      1704
#
#      March    April    May    June    July  August  September  October  \
# ...

# %%
for i in data['year']:
    if i != 2019 & i != 2018:
        print(0)
    else:
        print(i)
# Out:
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# ...

# %%
data_2018 = data[data['year'] == 2018]
data_2018
# Out:
#      year                 area               country  January  February  \
# 182  2018        ASIA PACIFIC             AUSTRALIAN    86658     70946
# 183  2018        ASIA PACIFIC                 BHUTAN       20        20
# 184  2018        ASIA PACIFIC             BANGLADESH     3153      2067
# 185  2018        ASIA PACIFIC                   FIJI       48        57
# 186  2018        ASIA PACIFIC               HONGKONG     1679      2721
# ..    ...                  ...                   ...      ...       ...
# 357  2018          MIDDLE EAST                TURKEY      899       615
# 358  2018          MIDDLE EAST  UNITED ARAB EMIRATES      170       132
# 359  2018          MIDDLE EAST                 YAMAN       98        49
# 360  2018          MIDDLE EAST                JORDAN      225       153
# 361  2018  OTHER NATIONALITIES   OTHER NATIONALITIES     6952      1704
#
#      March    April     May    June    July  August  September  October  \
# ...

# %%
kolom = ['January','February','March','April','May','June','July','August','September','October','November','December']
total_2018 = data_2018[kolom].sum()
total_2018
# Out:
# January      358065.0
# February     452423.0
# March        492678.0
# April        516777.0
# May          528512.0
# June         544550.0
# July         624366.0
# August       573766.0
# September    555903.0
# October      517889.0
# November     407213.0
# December     501211.0
# dtype: float64

# %%
total_kedatangan_2018 = total_2018.sum()
total_kedatangan_2018
# Out:
# 6073353.0

# %%
data_2019 = data[data['year'] == 2019]
data_2019
# Out:
#      year                 area               country  January  February  \
# 0    2019        ASIA PACIFIC             AUSTRALIAN    95536     67474
# 1    2019        ASIA PACIFIC                 BHUTAN       60        30
# 2    2019        ASIA PACIFIC             BANGLADESH     2262      2094
# 3    2019        ASIA PACIFIC                   FIJI       91        73
# 4    2019        ASIA PACIFIC               HONGKONG     1313      1367
# ..    ...                  ...                   ...      ...       ...
# 177  2019          MIDDLE EAST                TURKEY      688       529
# 178  2019          MIDDLE EAST  UNITED ARAB EMIRATES      181       141
# 179  2019          MIDDLE EAST                 YAMAN       77        75
# 180  2019          MIDDLE EAST                JORDAN      238       155
# 181  2019  OTHER NATIONALITIES   OTHER NATIONALITIES     2927       196
#
#      March    April    May    June    July  August  September  October  \
# ...

# %%
kolom = ['January','February','March','April','May','June','July','August','September','October','November','December']
total_2019 = data_2019[kolom].sum()
total_2019
# Out:
# January      456218.0
# February     437537.0
# March        449637.0
# April        476327.0
# May          485634.0
# June         549751.0
# July         594279.0
# August       616706.0
# September    590565.0
# October      568064.0
# November     497925.0
# December     552402.0
# dtype: float64

# %%
total_kedatangan_2019 = total_2019.sum()
total_kedatangan_2019
# Out:
# 6275045.0

# %%
mean_2018 = total_2018.mean()
mean_2018
# Out:
# 506112.75

# %%
mean_2019 = total_2019.mean()
mean_2019
# Out:
# 522920.4166666667

# %%
max_2018 = total_2018.max()
max_2018
# Out:
# 624366.0

# %%
min_2018 = total_2018.min()
min_2018
# Out:
# 358065.0

# %%
max_month_2018 = ""
count = 0
for i in total_2018:
    if i == max_2018:
        max_month_2018 = total_2018.index[count]
    count += 1
    
max_month_2018
# Out:
# 'July'

# %%
min_month_2018 = ""
count = 0
for i in total_2018:
    if i == min_2018:
        min_month_2018 = total_2018.index[count]
    count += 1

min_month_2018
# Out:
# 'January'

# %%
max_2019 = total_2019.max()
max_2019
# Out:
# 616706.0

# %%
min_2019 = total_2019.min()
min_2019
# Out:
# 437537.0

# %%
max_month_2019 = ""
count = 0
for i in total_2019:
    if i == max_2019:
        max_month_2019 = total_2019.index[count]
    count += 1

max_month_2019
# Out:
# 'August'

# %%
min_month_2019 = ""
count = 0
for i in total_2019:
    if i == min_2019:
        min_month_2019 = total_2019.index[count]
    count += 1

min_month_2019
# Out:
# 'February'

# %%
hasil = []
kolom = []
tahun = ['2018', '2019']
hasil_akhir = pd.DataFrame(hasil, columns = kolom, index = tahun)
hasil_akhir
# Out:
# Empty DataFrame
# Columns: []
# Index: [2018, 2019]

# %%
january = [total_2018['January'], total_2019['January']]
february = [total_2018['February'], total_2019['February']]
march = [total_2018['March'], total_2019['March']]
april = [total_2018['April'], total_2019['April']]
may = [total_2018['May'], total_2019['May']]
june = [total_2018['June'], total_2019['June']]
july = [total_2018['July'], total_2019['July']]
august = [total_2018['August'], total_2019['August']]
september = [total_2018['September'], total_2019['September']]
october = [total_2018['October'], total_2019['October']]
november = [total_2018['November'], total_2019['November']]
december = [total_2018['December'], total_2019['December']]
hasil_max = [max_month_2018, max_month_2019]
hasil_min = [min_month_2018, min_month_2019]
kedatangan = [total_kedatangan_2018, total_kedatangan_2019]
mean_kedatangan = [mean_2018, mean_2019]

hasil_akhir.insert(loc = 0, column = 'January', value = january)
hasil_akhir.insert(loc = 1, column = 'February', value = february)
hasil_akhir.insert(loc = 2, column = 'March', value = march)
hasil_akhir.insert(loc = 3, column = 'April', value = april)
hasil_akhir.insert(loc = 4, column = 'May', value = may)
hasil_akhir.insert(loc = 5, column = 'June', value = june)
hasil_akhir.insert(loc = 6, column = 'July', value = july)
hasil_akhir.insert(loc = 7, column = 'August', value = august)
hasil_akhir.insert(loc = 8, column = 'September', value = september)
hasil_akhir.insert(loc = 9, column = 'October', value = october)
hasil_akhir.insert(loc = 10, column = 'November', value = november)
hasil_akhir.insert(loc = 11, column = 'December', value = december)
hasil_akhir.insert(loc = 12, column = 'Max', value = hasil_max)
hasil_akhir.insert(loc = 13, column = 'Min', value = hasil_min)
hasil_akhir.insert(loc = 14, column = 'Total kedatangan setahun', value = kedatangan)
hasil_akhir.insert(loc = 15, column = 'Rata-rata kedatangan setahun', value = mean_kedatangan)

hasil_akhir
# Out:
#        January  February     March     April       May      June      July  \
# 2018  358065.0  452423.0  492678.0  516777.0  528512.0  544550.0  624366.0
# 2019  456218.0  437537.0  449637.0  476327.0  485634.0  549751.0  594279.0
#
#         August  September   October  November  December     Max       Min  \
# 2018  573766.0   555903.0  517889.0  407213.0  501211.0    July   January
# 2019  616706.0   590565.0  568064.0  497925.0  552402.0  August  February
#
#       Total kedatangan setahun  Rata-rata kedatangan setahun
# 2018                 6073353.0                 506112.750000
# 2019                 6275045.0                 522920.416667

# %%
hasil_akhir['January']
# Out:
# 2018    358065.0
# 2019    456218.0
# Name: January, dtype: float64

# %%
data_2018
# Out:
#      year                 area               country  January  February  \
# 182  2018        ASIA PACIFIC             AUSTRALIAN    86658     70946
# 183  2018        ASIA PACIFIC                 BHUTAN       20        20
# 184  2018        ASIA PACIFIC             BANGLADESH     3153      2067
# 185  2018        ASIA PACIFIC                   FIJI       48        57
# 186  2018        ASIA PACIFIC               HONGKONG     1679      2721
# ..    ...                  ...                   ...      ...       ...
# 357  2018          MIDDLE EAST                TURKEY      899       615
# 358  2018          MIDDLE EAST  UNITED ARAB EMIRATES      170       132
# 359  2018          MIDDLE EAST                 YAMAN       98        49
# 360  2018          MIDDLE EAST                JORDAN      225       153
# 361  2018  OTHER NATIONALITIES   OTHER NATIONALITIES     6952      1704
#
#      March    April     May    June    July  August  September  October  \
# ...

# %%
middle_east = data_2018[data_2018['area'] == 'ASIA PACIFIC']
middle_east_2018 = middle_east[kolom].sum()
middle_east_2018.sum()
# Out:
# 0.0

# %%
asean = data_2018[data_2018['area'] == 'ASEAN']
asean_2018 = asean[kolom].sum()
asean_2018.sum()
# Out:
# 0.0

# %%
africa = data_2018[data_2018['area'] == 'AFRICA']
africa_2018 = africa[kolom].sum()
africa_2018.sum()
# Out:
# 0.0

# %%
america = data_2018[data_2018['area'] == 'AMERICA']
america_2018 = america[kolom].sum()
america_2018.sum()
# Out:
# 0.0

# %%
europe = data_2018[data_2018['area'] == 'EUROPE']
europe_2018 = europe[kolom].sum()
europe_2018.sum()
# Out:
# 0.0

# %%
other = data_2018[data_2018['area'] == 'OTHER NATIONALITIES']
other_2018 = other[kolom].sum()
other_2018.sum()
# Out:
# 0.0

# %%
asia = data_2018[data_2018['area'] == 'ASIA PACIFIC']
asia_2018 = asia[kolom].sum()
asia_2018.sum()
# Out:
# 0.0

# %%
for i in coba['area']:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9692\2659518670.py in <module>
# ----> 1 for i in coba['area']:
#       2     print(i)
#
# NameError: name 'coba' is not defined

# %%
coba = data[data['area'] == 'ASIA PACIFIC']
coba

# %%
hasil_akhir['January']
