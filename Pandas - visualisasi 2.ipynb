# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = 'C:/Users/suniantara/Desktop/bootcamp/data/bali_tourist.csv'

data1 = pd.read_csv(url)
data1
# Out:
#      year                 area               country  January  February  \
# 0    2019        ASIA PACIFIC             AUSTRALIAN    95536     67474
# 1    2019        ASIA PACIFIC                 BHUTAN       60        30
# 2    2019        ASIA PACIFIC             BANGLADESH     2262      2094
# 3    2019        ASIA PACIFIC                   FIJI       91        73
# 4    2019        ASIA PACIFIC               HONGKONG     1313      1367
# ..    ...                  ...                   ...      ...       ...
# 357  2018          MIDDLE EAST                TURKEY      899       615
# 358  2018          MIDDLE EAST  UNITED ARAB EMIRATES      170       132
# 359  2018          MIDDLE EAST                 YAMAN       98        49
# 360  2018          MIDDLE EAST                JORDAN      225       153
# 361  2018  OTHER NATIONALITIES   OTHER NATIONALITIES     6952      1704
#
#      March    April    May    June    July  August  September  October  \
# ...

# %%
plt.figure(figsize=[15,5])
x = np.linspace(5,20,100)
plt.plot(x, np.sin(x));

# %%
data1.plot(x='country', y='January',figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='country'>

# %%
plt.figure(figsize=[15,5])
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x),linestyle=":",linewidth=4)
plt.plot(x,np.cos(x),linestyle="--",linewidth=4)
plt.plot(x,np.cos(2*x),linestyle="-.",linewidth=4);

# %%
data1.plot(x='country', y='January', linestyle=":",linewidth=4, figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='country'>

# %%
x1 = np.random.laplace(1, 0.8, 100)
x2 = np.random.normal(1, 2, 100)
plt.hist(x1, alpha=0.5, density=True, bins=20)
plt.hist(x2, alpha=0.5, density=True, bins=20)
# Out:
# (array([0.04784423, 0.04784423, 0.04784423, 0.1435327 , 0.16745482,
#         0.11961058, 0.21529905, 0.16745482, 0.19137693, 0.16745482,
#         0.19137693, 0.19137693, 0.23922117, 0.19137693, 0.09568847,
#         0.09568847, 0.        , 0.02392212, 0.02392212, 0.02392212]),
#  array([-2.5182002 , -2.10017699, -1.68215378, -1.26413057, -0.84610735,
#         -0.42808414, -0.01006093,  0.40796228,  0.8259855 ,  1.24400871,
#          1.66203192,  2.08005513,  2.49807835,  2.91610156,  3.33412477,
#          3.75214798,  4.1701712 ,  4.58819441,  5.00621762,  5.42424084,
#          5.84226405]),
#  <BarContainer object of 20 artists>)

# %%
january = data1['January']
februari = data1['February']
plt.hist(january, alpha=0.5, density=True, bins=10)
plt.hist(februari, alpha=0.5, density=True, bins=10)
# Out:
# (array([6.69600930e-05, 1.73172654e-06, 1.92414060e-07, 0.00000000e+00,
#         3.84828121e-07, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.92414060e-07, 1.92414060e-07]),
#  array([     0. ,  14356.7,  28713.4,  43070.1,  57426.8,  71783.5,
#          86140.2, 100496.9, 114853.6, 129210.3, 143567. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(data1['January']);

# %%
plt.figure(figsize=(8,6))
plt.scatter(x = data1['January'], y = data1['area'],alpha=0.5,label='January')
plt.scatter(x = data1['March'], y = data1['area'],alpha=0.5,label='March')

plt.xlabel("Tourist")
plt.ylabel("Area")
plt.title("Death Rates");

# %%
plt.figure(figsize=(8,6))
plt.plot(data1['January'],data1['area'], linestyle='--', label='januari')
plt.plot(data1['March'],data1['area'], linestyle='--', label='maret')
plt.legend()
plt.xlabel("Tourist")
plt.ylabel("Area")
plt.title("Death Rates");

# %%
plt.figure(figsize=(12,6))
plt.bar(data1['year'],data1['January'], label='januari', alpha=0.5)
plt.bar(data1['year'],data1['March'], label='maret', alpha=0.5)
plt.legend()
plt.xlabel("year")
plt.ylabel("tourist")
plt.title("Death Rates");

# %%
figure, ax1 = plt.subplots(figsize=(10,6))

ax1.plot(data1['year'],data1['January'], label='januari', c = 'red', alpha = 0.5)
ax2 = ax1.twinx()
ax2.plot(data1['year'],data1['March'], label='maret', alpha=0.5)

ax1.set_xlabel("years")
ax1.set_ylabel("birth rate")
ax2.set_ylabel("population change")
ax1.legend()
ax2.legend()
plt.title("Anderson County birth rate and population change");

# %%
figure, axes = plt.subplots(2,1,figsize=(10,6))

axes[0].plot(data1['year'],data1['January'], label='januari', c = 'red', alpha = 0.5)
axes[1].plot(data1['year'],data1['March'], label='maret', alpha=0.5)
axes[0].set_xlabel("years")
axes[0].set_ylabel("birth rate")
axes[1].set_ylabel("population change")
axes[0].legend()
axes[1].legend()
axes[0].set_title("Anderson County birth rate and population change");

# %%
plt.figure(figsize=(12,6))

plt.scatter(data1['January'],data1['March'], alpha=0.5, s = 50, c = data1['January'])
plt.xlabel("Tourist")
plt.ylabel("Tourist")
plt.title("Texas Counties Birth/Death Rates in 2013");

# %%
#assignment

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = 'C:/Users/suniantara/Desktop/bootcamp/data/SampleSuperstore.csv'
data1 = pd.read_csv(url)

data1
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9988  Standard Class  Corporate  United States           Athens     Georgia
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
#
# ...

# %%
data1.dropna()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9988  Standard Class  Corporate  United States           Athens     Georgia
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
#
# ...

# %%
group = data1.groupby('Ship Mode')['Quantity'].sum()
group
# Out:
# Ship Mode
# First Class        5693
# Same Day           1960
# Second Class       7421
# Standard Class    22797
# Name: Quantity, dtype: int64

# %%
group.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Ship Mode'>

# %%
plt.figure(figsize=[15,5])
sns.barplot(x='Ship Mode', y='Quantity', data=group.reset_index(), ci=0)
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Quantity'>

# %%
region = data1.groupby('Region')['Sales'].sum()
region
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725214.6645
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=[15,5])
sns.barplot(x='Sales', y='Region', data=region.reset_index(), ci=0)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Region'>

# %%
profit = data1.groupby('Category')['Profit'].sum()
plt.figure(figsize=[15,5])
sns.barplot(x='Category', y='Profit', data=profit.reset_index(), ci=0)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Profit'>

# %%
sales = data1.groupby('Category')['Sales'].sum()
plt.figure(figsize=[15,5])
sns.barplot(x='Category', y='Sales', data=sales.reset_index(), ci=0)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Sales'>

# %%
plt.figure(figsize=(12,6))

plt.scatter(data1['Discount'],data1['Profit'], alpha=0.5, s = 50, label = 'Profit')
plt.xlabel("Discount")
plt.ylabel("Profit")
plt.title("Discount dan Profit")
plt.legend()

# %%
discount_profit_df = data1[["Discount", "Profit"]]
discount_profit_df
# Out:
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9988      0.00   55.6470
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
#
# [9993 rows x 2 columns]

# %%
plt.scatter(discount_profit_df["Discount"], discount_profit_df["Profit"])

# %%
plt.plot(discount_profit_df.groupby("Discount").sum())
plt.scatter(discount_profit_df["Discount"], discount_profit_df["Profit"])
plt.show()

# %%
sum_of_profit_by_discount = discount_profit_df.groupby("Discount").sum()
x = sum_of_profit_by_discount.index.values
y = sum_of_profit_by_discount["Profit"].values

plt.scatter(x,y)
plt.plot(sum_of_profit_by_discount)
plt.show()
