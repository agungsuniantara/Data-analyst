# %%
num = 10
print(num)
# Out:
# 10

# %%
num = 1.3
print(num)
# Out:
# 1.3

# %%
name1 = 'C'
name2 = "C"
name3 = '''C'''
print(name1)
print(name2)
print(name3)
# Out:
# C
# C
# C

# %%
name1 = 'Koding Akademi'
name2 = "Koding Akademi"
name3 = '''Koding Akademi'''
print(name1)
print(name2)
print(name3)
# Out:
# Koding Akademi
# Koding Akademi
# Koding Akademi

# %%
isfalse = False
istrue = True
is_game_over = 1
is_game_over = 0

# true = 1, false = 0

cek = type(istrue)
print(cek)
# Out:
# <class 'bool'>

# %%
number1 = 10 
type_of_number = type(number1)
print(" Type of variable number 1 = ", type_of_number)
# Out:
#  Type of variable number 1 =  <class 'int'>

# %%
nama_musim = "Musim panas"
sum_math = 3 + 4 + 5
hard_math = sum_math
print(hard_math)
number_str = "081231231231"

type_integer = 10
type_float = 0.5
type_char = 'k'
type_string = "koding akademi"
type_boolean = True

print("type integer ", type_integer)
print("type float ", type_float)
print("type char ", type_char)
print("type string ", type_string)
print("type boolean ", type_boolean)

type_integer2 = float(10)
type_float2 = int(0.5)
type_integer3 = hex(675)
type_integer4 = str(119)

print("type integer to float", type(type_integer2))
print("type float to int", type(type_float2))
print("type integer to hex", type(type_integer3))
print("type integer to string", type(type_integer4))
print(type_integer3)
# Out:
# 12
# type integer  10
# type float  0.5
# type char  k
# type string  koding akademi
# type boolean  True
# type integer to float <class 'float'>
# type float to int <class 'int'>
# type integer to hex <class 'str'>
# type integer to string <class 'str'>
# 0x2a3
