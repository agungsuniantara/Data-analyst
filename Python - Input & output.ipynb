# %%
name = input("Nama = ")
print("Halo", name, "Selamat Datang di Koding Akademi!")
# Out:
# Nama = agung
# Halo agung Selamat Datang di Koding Akademi!

# %%
num = int(input("masukkan angka : "))

tambah = num + 1

print(tambah)
# Out:
# masukkan nama : 10
# 11

# %%
print("Koding \nAkademi")
print(name)
print('Belajar Coding')
# Out:
# Koding
# Akademi
# agung
# Belajar Coding

# %%
nama = "Robert"
print ("Hello", nama, "Selamat Datang di Koding Akademi")
# Out:
# Hello Robert Selamat Datang di Koding Akademi

# %%
print("Selamat datang teman", end = " ")
print("teman")
# Out:
# Selamat datang teman teman

# %%
print("koding akademi ","hello world ",'h', sep = "#")
# Out:
# koding akademi #hello world #h

# %%
a, b, c = map(int, input("Masukan angka : ").split(" "))
print("Angka : " , end = "")
print(a, b, c)
# Out:
# Masukan angka : 6 7 8
# Angka : 6 7 8

# %%
nama1 = ("nama#saya#agung").split("#")
nama2 = input("masukan nama : ").split()
print(nama2)
print(nama2[0])
# Out:
# masukan nama : agung ghaniya galih
# ['agung', 'ghaniya', 'galih']
# agung

# %%
List = list(map(int, input("Enter List elements : ").split()))
Set = set(map(int, input("Enter the Set elements :").split()))
print(List)
print(Set)
print(List[0])
# Out:
# Enter List elements : 1 2 3
# Enter the Set elements :1 2 3
# [1, 2, 3]
# {1, 2, 3}
# 1

# %%
var1 = "Koding Akademi"

# Output
print(f'Selamat Datang di {var1} Bagaimana kabar mu?')
# Out:
# Selamat Datang di Koding Akademi Bagaimana kabar mu?

# %%
var1 = 500
var2 = 1000

tambah = var1 + var2

kurang = var1 - var2

# Output
print('Nilai dari var1 : {} dan var2 : {}'.format(var1,var2))

print('{2} adalah penjumlahan dari {0} dan {1}'.format(var1,var2,tambah))

print('{sub_value} adalah pengurangan dari {value_1} dan {value_2}'.format(value_1 = var1 , value_2 = var2, sub_value = kurang))
# Out:
# Nilai dari var1 : 500 dan var2 : 1000
# 1500 adalah penjumlahan dari 500 dan 1000
# -500 adalah pengurangan dari 500 dan 1000

# %%
# terima user input
num = int(input("Masukan angka: "))
num1 = float(input("Masukan angka: "))
num2 = str(input("Masukan angka: "))

tambah = num + 5
tambah2 = num + 5

# Output
print("Jumlah {}".format(tambah))
print(f"jumlah {num} dari angka num1 {num1} dan angka num2 {num2}")
jumlah = ("Jumlah %d" %tambah)
print("Jumlah %d" %num1)
print("Jumlah %s" %num2)
# Out:
# Masukan angka: 5
# Masukan angka: 4
# Masukan angka: 3
# Jumlah 10
# jumlah 5 dari angka num1 4.0 dan angka num2 3
# Jumlah 4
# Jumlah 3

# %%
# assignment

nama = input("Masukkan nama : ")
umur = input("Masukkan umur : ")
alamat = input("masukkan alamat : ")

print("halo {} selamat datang di koding akademi".format(nama))
print("berikut identitas anda : ")
print("nama : {}".format(nama))
print("umur : {}".format(umur))
print("alamat : {}".format(alamat))
# Out:
# Masukkan nama : agung
# Masukkan umur : 20
# masukkan alamat : denpasar
# halo agung selamat datang di koding akademi
# berikut identitas anda :
# nama : agung
# umur : 20
# alamat : denpasar
