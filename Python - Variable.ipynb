# %%
nama = "Koding Akademi"
_nama = "Koding Akademi"
__nama = "Koding Akademi"
namaKu = "Koding Akademi"
namaku = "Koding Akademi"

# %%
nama = "Koding Akademi"
print(nama)
# Out:
# Koding Akademi

# %%
nama = "Koding Akademi"
print(nama)
del(nama)
print(nama)
# Out:
# Koding Akademi
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-93aecda27de5> in <module>
#       2 print(nama)
#       3 del(nama)
# ----> 4 print(nama)
#
# NameError: name 'nama' is not defined

# %%
#komentar 1 baris

"""

Komentar lebih dari satu baris dengan dibuka dan ditutup double quote 3x

"""

print("Hello World") #ini juga komentar

#print("Welcome")
# Out:
# Hello World
