# %%
print("hello world")
# Out:
# hello world

# %%
print("hello dunia")
# Out:
# hello dunia

# %%
nama = "koding akademi"
nama = 'koding akademi'

judul_course = "koding akademi"
judul_course = 'koding akademi'

if nama == "koding akademi":
  print("selamat datang di koding akademi")

# #ini komentar
# # "ini adalah contoh komentar"
# """ ini komentar """
# Out:
# selamat datang di koding akademi
# ' ini komentar '

# %%
down = 0
up = 100
for i in range(1,10):
  umur = int((up + down) / 2)
  jawaban = input('are you ' + str(umur) + " years old ?" )
  if jawaban == "correct":
    print("nice")
    break
  elif jawaban == "less":
    up = umur
  elif jawaban == "more":
    down = umur
  else:
    print("wrong answer")
# Out:
# are you 50 years old ?more
# are you 75 years old ?less
# are you 62 years old ?correct
# nice
