# %%
import pandas as pd

url = "C:/Users/suniantara/Desktop/bootcamp/data/Data-Penindakan-Pelanggaran-Lalu-Lintas.csv"
data = pd.read_csv(url)
data
# Out:
#        bulan                   wilayah  bap_tilang  stop_operasi  bap_polisi  \
# 0    Januari             Bidang Dalops          44           139           0
# 1    Januari    Sudinhub Jakarta Pusat          47             2          52
# 2    Januari    Sudinhub Jakarta Utara         166            27           0
# 3    Januari  Sudinhub Jakarta Selatan          44             1           0
# 4    Januari    Sudinhub Jakarta Barat         184            70           0
# 5    Januari    Sudinhub Jakarta Timur         191           141           0
# 6   Februari             Bidang Dalops          37           143           0
# 7   Februari    Sudinhub Jakarta Pusat          48             7          42
# 8   Februari    Sudinhub Jakarta Utara         251            27          31
# 9   Februari  Sudinhub Jakarta Selatan         129            12           0
# 10  Februari    Sudinhub Jakarta Barat         229            60           0
# ...

# %%
data['stop_operasi'].mean()
# Out:
# 62.69047619047619

# %%
data['stop_operasi'].median()
# Out:
# 46.5

# %%
data['stop_operasi'].mode()
# Out:
# 0    10
# Name: stop_operasi, dtype: int64

# %%
data['stop_operasi'].var()
# Out:
# 2750.755516840883

# %%
data['stop_operasi'].std()
# Out:
# 52.44764548424346

# %%
data['stop_operasi'].quantile([0.25,0.25,0.25,0.25])
# Out:
# 0.25    20.25
# 0.25    20.25
# 0.25    20.25
# 0.25    20.25
# Name: stop_operasi, dtype: float64

# %%
data['stop_operasi'].skew()
# Out:
# 0.6546836399029299

# %%
print(data.dtypes)
# Out:
# bulan                  object
# wilayah                object
# bap_tilang              int64
# stop_operasi            int64
# bap_polisi              int64
# stop_operasi_polisi     int64
# penderekan              int64
# ocp_roda_dua            int64
# ocp_roda_empat          int64
# angkut_motor            int64
# dtype: object

# %%
data['bulan'] = pd.Categorical(data['bulan'])

# %%
print(data.dtypes)
# Out:
# bulan                  category
# wilayah                  object
# bap_tilang                int64
# stop_operasi              int64
# bap_polisi                int64
# stop_operasi_polisi       int64
# penderekan                int64
# ocp_roda_dua              int64
# ocp_roda_empat            int64
# angkut_motor              int64
# dtype: object
