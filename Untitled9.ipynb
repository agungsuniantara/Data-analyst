# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('C:/Users/suniantara/Desktop/bootcamp/data/dataset/heart.csv')

data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
data['age'].hist()
# Out:
# <AxesSubplot:>

# %%
data['sex'].hist()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data1 = pd.read_csv('C:/Users/suniantara/Desktop/bootcamp/data/dataset/country_vaccinations.csv')

data1
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 53590     Zimbabwe      ZWE  2021-10-22           5814790.0
# 53591     Zimbabwe      ZWE  2021-10-23           5826876.0
# 53592     Zimbabwe      ZWE  2021-10-24           5836363.0
# 53593     Zimbabwe      ZWE  2021-10-25           5848934.0
# 53594     Zimbabwe      ZWE  2021-10-26           5866629.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
data_zimbabwe = data1[data1['country'] == 'Zimbabwe'].dropna()
data_zimbabwe
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 53376  Zimbabwe      ZWE  2021-03-22             44120.0            43840.0
# 53377  Zimbabwe      ZWE  2021-03-23             45743.0            44681.0
# 53378  Zimbabwe      ZWE  2021-03-24             52439.0            49950.0
# 53379  Zimbabwe      ZWE  2021-03-25             59533.0            55438.0
# 53380  Zimbabwe      ZWE  2021-03-26             68208.0            61639.0
# ...         ...      ...         ...                 ...                ...
# 53590  Zimbabwe      ZWE  2021-10-22           5814790.0          3271638.0
# 53591  Zimbabwe      ZWE  2021-10-23           5826876.0          3276746.0
# 53592  Zimbabwe      ZWE  2021-10-24           5836363.0          3281618.0
# 53593  Zimbabwe      ZWE  2021-10-25           5848934.0          3287996.0
# 53594  Zimbabwe      ZWE  2021-10-26           5866629.0          3294687.0
#
# ...

# %%
data_zimbabwe['people_vaccinated'].plot()
# Out:
# <AxesSubplot:>
