# %%
import pandas as pd

url = 'C:/Users/suniantara/Desktop/bootcamp/data/package_tourism.csv'
data = pd.read_csv(url)
data
# Out:
#     Package      City                   Place_Tourism1  \
# 0         1   Jakarta                Pasar Tanah Abang
# 1         2   Jakarta                Pasar Tanah Abang
# 2         3   Jakarta            Perpustakaan Nasional
# 3         4   Jakarta                     Pulau Tidung
# 4         5   Jakarta            Museum Satria Mandala
# ..      ...       ...                              ...
# 95       96  Surabaya      Ekowisata Mangrove Wonorejo
# 96       97  Surabaya                Ciputra Waterpark
# 97       98  Surabaya    Museum Kesehatan Dr. Adhyatma
# 98       99  Surabaya  Taman Ekspresi Dan Perpustakaan
# 99      100  Surabaya              Taman Buah Surabaya
#
#               Place_Tourism2                  Place_Tourism3  \
# 0               Taman Ayodya                  Museum Tekstil
# 1         Pasar Taman Puring            Pasar Petak Sembilan
# 2                      Monas                 Masjid Istiqlal
# ...

# %%
data = pd.read_csv(url, header = None)
data
# Out:
#            0         1                                2  \
# 0    Package      City                   Place_Tourism1
# 1          1   Jakarta                Pasar Tanah Abang
# 2          2   Jakarta                Pasar Tanah Abang
# 3          3   Jakarta            Perpustakaan Nasional
# 4          4   Jakarta                     Pulau Tidung
# ..       ...       ...                              ...
# 96        96  Surabaya      Ekowisata Mangrove Wonorejo
# 97        97  Surabaya                Ciputra Waterpark
# 98        98  Surabaya    Museum Kesehatan Dr. Adhyatma
# 99        99  Surabaya  Taman Ekspresi Dan Perpustakaan
# 100      100  Surabaya              Taman Buah Surabaya
#
#                             3                               4  \
# 0              Place_Tourism2                  Place_Tourism3
# 1                Taman Ayodya                  Museum Tekstil
# 2          Pasar Taman Puring            Pasar Petak Sembilan
# ...

# %%
data.columns = ['a','b','c','d','e','f','g']
data
# Out:
#            a         b                                c  \
# 0    Package      City                   Place_Tourism1
# 1          1   Jakarta                Pasar Tanah Abang
# 2          2   Jakarta                Pasar Tanah Abang
# 3          3   Jakarta            Perpustakaan Nasional
# 4          4   Jakarta                     Pulau Tidung
# ..       ...       ...                              ...
# 96        96  Surabaya      Ekowisata Mangrove Wonorejo
# 97        97  Surabaya                Ciputra Waterpark
# 98        98  Surabaya    Museum Kesehatan Dr. Adhyatma
# 99        99  Surabaya  Taman Ekspresi Dan Perpustakaan
# 100      100  Surabaya              Taman Buah Surabaya
#
#                             d                               e  \
# 0              Place_Tourism2                  Place_Tourism3
# 1                Taman Ayodya                  Museum Tekstil
# 2          Pasar Taman Puring            Pasar Petak Sembilan
# ...

# %%
print("baris data = ",data.shape[0]," kolom data = ",data.shape[1])
# Out:
# baris data =  101  kolom data =  7

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       101 non-null    object
#  1   b       101 non-null    object
#  2   c       101 non-null    object
#  3   d       101 non-null    object
#  4   e       101 non-null    object
#  5   f       67 non-null     object
#  6   g       40 non-null     object
# dtypes: object(7)
# memory usage: 5.6+ KB

# %%
data.head()
# Out:
#          a        b                      c                   d  \
# 0  Package     City         Place_Tourism1      Place_Tourism2
# 1        1  Jakarta      Pasar Tanah Abang        Taman Ayodya
# 2        2  Jakarta      Pasar Tanah Abang  Pasar Taman Puring
# 3        3  Jakarta  Perpustakaan Nasional               Monas
# 4        4  Jakarta           Pulau Tidung      Pulau Bidadari
#
#                       e               f               g
# 0        Place_Tourism3  Place_Tourism4  Place_Tourism5
# 1        Museum Tekstil             NaN             NaN
# 2  Pasar Petak Sembilan             NaN             NaN
# 3       Masjid Istiqlal             NaN             NaN
# 4            Pulau Pari   Pulau Pramuka   Pulau Pelangi

# %%
data.tail()
# Out:
#        a         b                                c                         d  \
# 96    96  Surabaya      Ekowisata Mangrove Wonorejo     Taman Harmoni Keputih
# 97    97  Surabaya                Ciputra Waterpark             Kenjeran Park
# 98    98  Surabaya    Museum Kesehatan Dr. Adhyatma  Patung Buddha Empat Rupa
# 99    99  Surabaya  Taman Ekspresi Dan Perpustakaan   Museum De Javasche Bank
# 100  100  Surabaya              Taman Buah Surabaya       Hutan Bambu Keputih
#
#                                   e                                f  \
# 96              Taman Kunang-Kunang  Taman Ekspresi Dan Perpustakaan
# 97          Kebun Binatang Surabaya      Food Junction Grand Pakuwon
# 98             Taman Hiburan Rakyat                    Taman Bungkul
# 99   Surabaya Museum (Gedung Siola)              Museum Mpu Tantular
# 100                Taman Barunawati             Kebun Bibit Wonorejo
#
#                                     g
# 96            Museum De Javasche Bank
# ...

# %%
data.head(3)
# Out:
#          a        b                  c                   d  \
# 0  Package     City     Place_Tourism1      Place_Tourism2
# 1        1  Jakarta  Pasar Tanah Abang        Taman Ayodya
# 2        2  Jakarta  Pasar Tanah Abang  Pasar Taman Puring
#
#                       e               f               g
# 0        Place_Tourism3  Place_Tourism4  Place_Tourism5
# 1        Museum Tekstil             NaN             NaN
# 2  Pasar Petak Sembilan             NaN             NaN

# %%
data.tail(3)
# Out:
#        a         b                                c                         d  \
# 98    98  Surabaya    Museum Kesehatan Dr. Adhyatma  Patung Buddha Empat Rupa
# 99    99  Surabaya  Taman Ekspresi Dan Perpustakaan   Museum De Javasche Bank
# 100  100  Surabaya              Taman Buah Surabaya       Hutan Bambu Keputih
#
#                                   e                     f  \
# 98             Taman Hiburan Rakyat         Taman Bungkul
# 99   Surabaya Museum (Gedung Siola)   Museum Mpu Tantular
# 100                Taman Barunawati  Kebun Bibit Wonorejo
#
#                                     g
# 98       Taman Flora Bratang Surabaya
# 99   Taman Air Mancur Menari Kenjeran
# 100                       Taman Mundu
